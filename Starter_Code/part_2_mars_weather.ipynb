# %% [markdown]
# # Module 11 Challenge
# ## Deliverable 2: Scrape and Analyze Mars Weather Data

# %%
# Import relevant libraries
from splinter import Browser
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import pandas as pd

# %%
browser = Browser('chrome')

# %% [markdown]
# ### Step 1: Visit the Website
#
# Use automated browsing to visit the [Mars Temperature Data Site](https://static.bc-edx.com/data/web/mars_facts/temperature.html). Inspect the page to identify which elements to scrape.
#
#    > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools to discover whether the table contains usable classes.

# %%
# Visit the website
# https://static.bc-edx.com/data/web/mars_facts/temperature.html
url = "https://static.bc-edx.com/data/web/mars_facts/temperature.html"
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Table
#
# Create a Beautiful Soup object and use it to scrape the data in the HTML table.
#
# Note that this can also be achieved by using the Pandas `read_html` function. However, use Beautiful Soup here to continue sharpening your web scraping skills.

# %%
# Save the HTML from the browser
html = browser.html

# Create a Beautiful Soup Object
soup = BeautifulSoup(html, 'html.parser')

# %%
# Extract all rows of data

rows =soup.find_all('tr', class_ = 'data-row')
for row in rows:
    print(row)
# Out:
# <tr class="data-row">
# <td>2</td>
# <td>2012-08-16</td>
# <td>10</td>
# <td>155</td>
# <td>6</td>
# <td>-75.0</td>
# <td>739.0</td>
# </tr>
# <tr class="data-row">
# <td>13</td>
# <td>2012-08-17</td>
# <td>11</td>
# <td>156</td>
# <td>6</td>
# <td>-76.0</td>
# <td>740.0</td>
# </tr>
# <tr class="data-row">
# <td>24</td>
# <td>2012-08-18</td>
# <td>12</td>
# <td>156</td>
# <td>6</td>
# <td>-76.0</td>
# <td>741.0</td>
# </tr>
# <tr class="data-row">
# <td>35</td>
# <td>2012-08-19</td>
# <td>13</td>
# <td>157</td>
# <td>6</td>
# <td>-74.0</td>
# <td>732.0</td>
# </tr>
# <tr class="data-row">
# <td>46</td>
# <td>2012-08-20</td>
# <td>14</td>
# <td>157</td>
# <td>6</td>
# <td>-74.0</td>
# <td>740.0</td>
# </tr>
# <tr class="data-row">
# <td>57</td>
# <td>2012-08-21</td>
# <td>15</td>
# <td>158</td>
# <td>6</td>
# <td>-78.0</td>
# <td>740.0</td>
# </tr>
# <tr class="data-row">
# <td>68</td>
# <td>2012-08-22</td>
# <td>16</td>
# <td>158</td>
# <td>6</td>
# <td>-77.0</td>
# <td>740.0</td>
# ...

# %% [markdown]
# ### Step 3: Store the Data
#
# Assemble the scraped data into a Pandas DataFrame. The columns should have the same headings as the table on the website. Here’s an explanation of the column headings:
#
# * `id`: the identification number of a single transmission from the Curiosity rover
# * `terrestrial_date`: the date on Earth
# * `sol`: the number of elapsed sols (Martian days) since Curiosity landed on Mars
# * `ls`: the solar longitude
# * `month`: the Martian month
# * `min_temp`: the minimum temperature, in Celsius, of a single Martian day (sol)
# * `pressure`: The atmospheric pressure at Curiosity's location

# %%
# Create an empty list
mars_weather_data = []

# Loop through the scraped data to create a list of rows
for row_result in rows:
    result = row_result.find_all('td')

    row_data = []
    for data in range(0,7):
        row_data.append(result[data].text)
    
    mars_weather_data.append(row_data)
mars_weather_data[0:15]
# Out:
# [['2', '2012-08-16', '10', '155', '6', '-75.0', '739.0'],
#  ['13', '2012-08-17', '11', '156', '6', '-76.0', '740.0'],
#  ['24', '2012-08-18', '12', '156', '6', '-76.0', '741.0'],
#  ['35', '2012-08-19', '13', '157', '6', '-74.0', '732.0'],
#  ['46', '2012-08-20', '14', '157', '6', '-74.0', '740.0'],
#  ['57', '2012-08-21', '15', '158', '6', '-78.0', '740.0'],
#  ['68', '2012-08-22', '16', '158', '6', '-77.0', '740.0'],
#  ['79', '2012-08-23', '17', '159', '6', '-76.0', '742.0'],
#  ['112', '2012-08-27', '21', '161', '6', '-74.0', '741.0'],
#  ['114', '2012-08-28', '22', '162', '6', '-74.0', '742.0'],
#  ['123', '2012-08-29', '23', '162', '6', '-75.0', '741.0'],
#  ['134', '2012-08-30', '24', '163', '6', '-75.0', '742.0'],
#  ['145', '2012-08-31', '25', '163', '6', '-75.0', '743.0'],
#  ['156', '2012-09-01', '26', '164', '6', '-76.0', '745.0'],
#  ['163', '2012-09-02', '27', '164', '6', '-75.0', '743.0']]

# %%
# Create a Pandas DataFrame by using the list of rows and a list of the column names
col_names = ['id',	'terrestrial_date',	"sol",	"ls", "month", "min_temp", "pressure"]
df = pd.DataFrame(mars_weather_data, columns = col_names)

# %%
# Confirm DataFrame was created successfully
df
# Out:
#         id terrestrial_date   sol   ls month min_temp pressure
# 0        2       2012-08-16    10  155     6    -75.0    739.0
# 1       13       2012-08-17    11  156     6    -76.0    740.0
# 2       24       2012-08-18    12  156     6    -76.0    741.0
# 3       35       2012-08-19    13  157     6    -74.0    732.0
# 4       46       2012-08-20    14  157     6    -74.0    740.0
# ...    ...              ...   ...  ...   ...      ...      ...
# 1862  1889       2018-02-23  1973  133     5    -78.0    730.0
# 1863  1892       2018-02-24  1974  134     5    -77.0    729.0
# 1864  1894       2018-02-25  1975  134     5    -76.0    729.0
# 1865  1893       2018-02-26  1976  135     5    -77.0    728.0
# 1866  1895       2018-02-27  1977  135     5    -77.0    727.0
#
# [1867 rows x 7 columns]

# %% [markdown]
# ### Step 4: Prepare Data for Analysis
#
# Examine the data types that are currently associated with each column. If necessary, cast (or convert) the data to the appropriate `datetime`, `int`, or `float` data types.
#
#   > **Hint** You can use the Pandas `astype` and `to_datetime` methods to accomplish this task.

# %%
# Examine data type of each column
df.dtypes
# Out:
# id                  object
# terrestrial_date    object
# sol                 object
# ls                  object
# month               object
# min_temp            object
# pressure            object
# dtype: object

# %%
# Change data types for data analysis
df['terrestrial_date'] = pd.to_datetime(df['terrestrial_date'].squeeze().tolist()) #mars_weather_df['terrestrial_date'].squeeze(): This step extracts the terrestrial_date column from the DataFrame and squeezes it into a Series.
                    #.tolist(): This converts the Series into a list of strings
df[['sol','ls','month']] = df[['sol','ls','month']].astype('int64') #.astype('int64'): This converts the selected columns to the int64 data type.
df[['min_temp','pressure']] =df[['min_temp','pressure']].astype('float64')

# %%
# Confirm type changes were successful by examining data types again
df.dtypes
# Out:
# id                          object
# terrestrial_date    datetime64[ns]
# sol                          int64
# ls                           int64
# month                        int64
# min_temp                   float64
# pressure                   float64
# dtype: object

# %% [markdown]
# ### Step 5: Analyze the Data
#
# Analyze your dataset by using Pandas functions to answer the following questions:
#
# 1. How many months exist on Mars?
# 2. How many Martian (and not Earth) days worth of data exist in the scraped dataset?
# 3. What are the coldest and the warmest months on Mars (at the location of Curiosity)? To answer this question:
#     * Find the average the minimum daily temperature for all of the months.
#     * Plot the results as a bar chart.
# 4. Which months have the lowest and the highest atmospheric pressure on Mars? To answer this question:
#     * Find the average the daily atmospheric pressure of all the months.
#     * Plot the results as a bar chart.
# 5. About how many terrestrial (Earth) days exist in a Martian year? To answer this question:
#     * Consider how many days elapse on Earth in the time that Mars circles the Sun once.
#     * Visually estimate the result by plotting the daily minimum temperature.

# %%
# 1. How many months are there on Mars?
mars_month = df.groupby('month')['month'].count()
mars_month
# Out:
# month
# 1     174
# 2     178
# 3     192
# 4     194
# 5     149
# 6     147
# 7     142
# 8     141
# 9     134
# 10    112
# 11    138
# 12    166
# Name: month, dtype: int64

# %%
# 2. How many sols (Martian days) worth of data are there?
sols_worth = df['sol'].count()
sols_worth
# Out:
# 1867

# %%
# 3. What is the average minimum temperature by month?
min_temp_avg = df.groupby('month')['min_temp'].mean()
min_temp_avg
# Out:
# month
# 1    -77.160920
# 2    -79.932584
# 3    -83.307292
# 4    -82.747423
# 5    -79.308725
# 6    -75.299320
# 7    -72.281690
# 8    -68.382979
# 9    -69.171642
# 10   -71.982143
# 11   -71.985507
# 12   -74.451807
# Name: min_temp, dtype: float64

# %%
# Plot the average minimum temperature by month
chart = min_temp_avg.plot(kind='bar')
chart.set_xlabel('Month')
chart.set_ylabel('Temperature')
chart.set_title('Average minimum daily temperature by months')
plt.tight_layout()
plt.savefig('Average minimum daily temperature by months')
plt.show()

# %%
# Identify the coldest and hottest months in Curiosity's location by sorting the previous graph
cold_hot_order = min_temp_avg.sort_values(ascending=True)
ordered = cold_hot_order.plot(kind='bar')
ordered.set_xlabel('Month')
ordered.set_ylabel('Temperature')
ordered.set_title('Average minimum daily temperature by months')
plt.tight_layout()
plt.savefig('Sorted average minimum daily temperature by months')
plt.show()

# %%
# 4. What is the average pressure by month?
avg_pressure = df.groupby('month')['pressure'].mean()
avg_pressure
# Out:
# month
# 1     862.488506
# 2     889.455056
# 3     877.322917
# 4     806.329897
# 5     748.557047
# 6     745.054422
# 7     795.105634
# 8     873.829787
# 9     913.305970
# 10    887.312500
# 11    857.014493
# 12    842.156627
# Name: pressure, dtype: float64

# %%
# Plot the average pressure by month

pressure_chart = avg_pressure.plot(kind='bar')
pressure_chart.set_xlabel('Month')
pressure_chart.set_ylabel(' Atmospheric Pressure')
pressure_chart.set_title('Average daily atmospheric pressure by months')
plt.tight_layout()
plt.savefig('Average daily atmospheric pressure by months')
plt.show()

# %%
# Identify the lowest and highest pressure months in Curiosity's location by sorting the previous graph
pressure_chart_sort = avg_pressure.sort_values(ascending=True)
pressure_chart = pressure_chart_sort.plot(kind='bar')
pressure_chart.set_xlabel('Month')
pressure_chart.set_ylabel(' Atmospheric Pressure')
pressure_chart.set_title('Average daily atmospheric pressure by months')
plt.tight_layout()
plt.savefig('Sorted average daily atmospheric pressure by months')
plt.show()

# %%
# 5. How many terrestrial (Earth) days are there in a Martian year?
earth_days = df[['terrestrial_date','min_temp']].copy()
earth_days
# Out:
#      terrestrial_date  min_temp
# 0          2012-08-16     -75.0
# 1          2012-08-17     -76.0
# 2          2012-08-18     -76.0
# 3          2012-08-19     -74.0
# 4          2012-08-20     -74.0
# ...               ...       ...
# 1862       2018-02-23     -78.0
# 1863       2018-02-24     -77.0
# 1864       2018-02-25     -76.0
# 1865       2018-02-26     -77.0
# 1866       2018-02-27     -77.0
#
# [1867 rows x 2 columns]

# %%
# Visually estimate the result by plotting the daily minimum temperature of each observation in the data set.
start_date = earth_days['terrestrial_date'].iloc[0]
start_date
# Out:
# Timestamp('2012-08-16 00:00:00')

# %%
earth_days['terrestrial_days'] = (earth_days['terrestrial_date'] - start_date).dt.days

earth_days
# Out:
#      terrestrial_date  min_temp  terrestrial_days
# 0          2012-08-16     -75.0                 0
# 1          2012-08-17     -76.0                 1
# 2          2012-08-18     -76.0                 2
# 3          2012-08-19     -74.0                 3
# 4          2012-08-20     -74.0                 4
# ...               ...       ...               ...
# 1862       2018-02-23     -78.0              2017
# 1863       2018-02-24     -77.0              2018
# 1864       2018-02-25     -76.0              2019
# 1865       2018-02-26     -77.0              2020
# 1866       2018-02-27     -77.0              2021
#
# [1867 rows x 3 columns]

# %%
orig_long=df['ls'].loc[0]
orig_long
same_long=df.loc[df['ls']==orig_long]
same_long
# Out:
#         id terrestrial_date   sol   ls  month  min_temp  pressure
# 0        2       2012-08-16    10  155      6     -75.0     739.0
# 598    621       2014-07-03   678  155      6     -77.0     739.0
# 599    624       2014-07-04   679  155      6     -77.0     738.0
# 1249  1274       2016-05-20  1346  155      6     -75.0     737.0
# 1250  1277       2016-05-21  1347  155      6     -75.0     736.0

# %%
alpha=same_long['terrestrial_date'].loc[0]
date_after_one_martial_year = same_long['terrestrial_date'].iloc[1]
one_martial_year= date_after_one_martial_year-alpha
print(f"One Martial Year is equivalent to {one_martial_year} days on Earth")
# Out:
# One Martial Year is equivalent to 686 days 00:00:00 days on Earth

# %%
plt.bar(df['sol'],df['min_temp'])
plt.xlabel("Days")
plt.ylabel("Minimum Temperature ")
plt.title('Daily minimum temperature')
plt.savefig('Daily minimum temperature')
plt.show()

# %% [markdown]
# #### Minimum Temperature
#
# YOUR ANALYSIS HERE:
# The third month has the coldest minimum temperature on Mars, and the eighth month is the warmest.

# %% [markdown]
# #### Atmospheric Pressure
#
# YOUR ANALYSIS HERE:
# Atmospheric pressure is, on average, lowest in the sixth month and highest in the ninth month.

# %% [markdown]
# #### Year Length
#
# YOUR ANALYSIS HERE:
# A year on Mars lasts 669.6 sols, which is the same as 687 Earth days.

# %% [markdown]
# ### Step 6: Save the Data
#
# Export the DataFrame to a CSV file.

# %%
# Write the data to a CSV
df.to_csv('mars_weather_data.csv', index=False)

# %%
browser.quit()
